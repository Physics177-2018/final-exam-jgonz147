# %% [markdown]
# # P177: Final Exam
# Spring 2018
#
# **Due:** please complete by **Friday, June 15th**.
# Pro-tip: do this way before then.
#
# **iEval:** please complete the [iEval](https://ieval.ucr.edu/) before **Friday, June 8th**.
#
#
# *Julián Gonzalez*

# %% [markdown]
# ## 1. Kaggle Tutorial
#
# 1. Create a Kaggle account and navigate to the "[Titanic: Machine Learning from Disaster](https://www.kaggle.com/c/titanic)" competition. Read a bit about the challenge.
#
# 2. Navigate to Helge Bjorland's "[Interactive Data Science Tutorial](https://www.kaggle.com/helgejo/an-interactive-data-science-tutorial)" that uses the Titanic dataset. (**Note:** in class we used [Rochelle Silva's tutorial](https://www.kaggle.com/rochellesilva/simple-tutorial-for-beginners), the Bjorland tutorial is probably a little more insightful.)
#
# 3. **Fork** the tutorial and go through it. Run everything. You are not required to complete the "exercises" (cells where you have to type code), but you get extra credit if you do.
#
# 4. Download the completed tutorial as a Jupyter notebook (`ipynb` file). Upload that notebook to your GitHub repository for this final.

# %% [markdown]
# ## 2. Answer the Following Questions
#
# These are real questions where I'd like you to write a few sentences about your code. The goal is to show that you've thought carefully about your code and can say something insightful about your work.

# %% [markdown]
# ### a) What was your favorite homework problem? What did you learn from doing it?
#
# <br>My favorite homework problem was Homework 5b<br>
# <br>In this homework set, we tackled a computational error<br>
# <br>that arised from an algorithm called Runge-Kutta.<br>
# <br>The algorithm was used to approximate the solution<br>
# <br>for a first order differential equation for a simple pendulum<br>
# <br>and the algorithm worked very well for ODE's that didn't<br>
# <br>have cyclic motion, but since the pendulum is time-invarient<br>
# <br>Runge-Kutta method was incaplable of modeling the pendulum.<br>
# <br>To fix this problem we needed to use a different approximation<br>
# <br>method called Leap-frog. The Leap-frog method was successful for<br>
# <br>modeling the simple pendulum since it took to observation points<br>
# <br>such as postion and velocity for updating the trajectory of the<br>
# <br>pendulum, whereas the RK method was only using the slope of a given<br>
# <br>postion to predict the next tracjectory of the pendulum.<br>
# <br>After completing this problem set, I learned that one powerful algorithm<br>
# <br>may not be useful for different physical systems that are common is physics,<Br>
# <br>so knowing how your system should behaves if always important before<Br>
# <br>implementing an ODE solver.<br>

# %% [markdown]
# ### b) What was the most difficult problem? What was confusing or frustrating about it?
#
# <br>The most difficult probelm was Homework assignment 8B<br>
# <br>since it was the fist time we took off the training wheels<br>
# <br>of the psuedo code for the python notebook.<br>
# <br>I only felt confused since I need to master how to<br>
# <br>build double arrays with smart for loops. For some<br>
# <br>reason my brain cannot see how to translate my white board<br>
# <br>into a double for loop code. I was being negative in my mind<br>
# <br>about the assignment, and did not give myself time to<br>
# <br>think further about developing the code. Over the break<br>
# <br>I will be working on the problem to gain the experience!<br>

# %% [markdown]
# ### c) In your own words, give an example of a problem where you would use Markov Chain Monte Carlo (MCMC). Briefly describe how MCMC works.
#
# <br>An example for the use of MCMC, would be<br>
# <br>the annealing process for an Ice Cube to freeze<br>
# <br>into a perfect / clear Ice Cube.<br>
# <br>The reason for using the MCMC method<br>
# <br>is to predict a set of microstates built from<br>
# <br>the probility distrubition that dictate the configuration<br>
# <br>of the state, and since thermodynamics is generated by <br>
# <br>large set if microstates, the MCMC uses the probability equation<br>
# <br>$ P = exp(T(E_i-E_f))$<br>
# <br>for decidinig which state is favorable for making a tranistion<br>
# <br>once a random configuration of states has been created<br>

# %% [markdown]
# ### d) ELI5: Pick one technical idea from the course and explain it to a five-year-old.
#
# <br>As a child you learn how to find the area of an object.<br>
# <br>You first started with using the lenght & width of an<br>
# <br>object such as a triangle, square, or any many-sided object.<br>
# <br>But once you get into college, you quickly learn that finding<br>
# <br>the area of an object can be done with lines or curves. In this<br>
# <br>grown up course, we have used a method called integration, but instead of<br>
# <br>sticking with one shape like the square, we use a trapizoid to approximate the<br>
# <br>true area of an object, but the trick is to use a large sets of trapizoids to<br>
# <br>get an even better approximation. A famous physicist came up with an idea to do this<br>
# <br>since he understood that a function gives you the height of an object and the difference from<br>
# <br>that same function at a different point gives a different height. With these two ideas in mind, he<br>
# <br>he was able to come up with small sqaure for the object.<br>
#
# <img src="int.PNG">

# %% [markdown]
# ## 3. Evaluation (not for a grade)
#
# I hope you filled out the `iEval` before Jun 8th. In this cell, please feel free to share constructive criticism about the course. What did you like? What did you not like? Are there topics that you really wish we covered or didn't cover? What should I know to be a better lecturer?
#
# <br>First: I truly enjoyed your energy as a professor, and your<br>
# <br>willingness to explain and teach ideas to us.<br>
# <br>You made sure each day to ask us questions (I personally feel that asking us question<br>
# <br> in class is like making us flex our brains as if it was gym time for the brain!)<br>
# <br>since you were able to find immediate feedback on what we knew and did not know. So thank you for that<br>
# <br>Second: I felt that many of us did not help each other learn the codes very well. Me and steven helped each<br>
# <br>as much as we could, but if other students took action with us, I truly believe we could have taken<br>
# <br>this class to a new level!<br>
# <br>Third: my only suggestion would be to make the homeworks a litte more baby steps to help get<br>
# <br>us the simple knowledge of building arrays for different sizes since I felt the course<br>
# <br>stressed knowing this concept quite dearly.<br>
# <br>Overall, I enjoyed your course over all the courses I have taken at UCR since you asked me<br>
# <br>and other students questions to grow and think on the spot! Felt like being a physicist everytime<br>
# <br>I entered into lecture with you and the students!<br>

# %% [markdown]
# ## Closing thoughts
#
# It's been a real joy to be part of this class---I was really impressed by each of your midterm presentations and have had a lot of fun with our discussions. In whatever is ahead of you beyond this class, I look forward to hearing how you each succeed.
#
# I encourage you to make your GitHub repositories public (you may need to duplicate them) so that you can show them off to the world.
